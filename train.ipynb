# %% [markdown]
# # Blood Test Analysis

# %% [markdown]
# ## Load Dataset

# %%
# use python pandas library
# Out:
# Running cells with 'venv (Python 3.10.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/diyashrivastava/Projects/healthcare-app/venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ## Preprocessing - where you split into test/train split

# %%
# split test/train (and maybe)

# %% [markdown]
# ## Model Training

# %%
# scikit-learn library to train + numpy library to print to calculate evaluation metrics

# %% [markdown]
# ## Evaluation Visualization

# %%
# Matplotlib or seaborn library 
# Present confusion matrix
